# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_node('D', label='Difficulty')
G.add_node('I', label='Intelligence')
G.add_node('G', label='Grade')
G.add_edge('D', 'G')
G.add_edge('I', 'G')
pos = {'D': (0, 1), 'I': (1, 1), 'G': (1, 0)}
nx.draw(G, pos, with_labels=True, node_size=1000, node_color='skyblue', font_size=10)
plt.title("Bayesian Network")
plt.show()

# %%
from keras.models import load_model

# %%
import datetime
date = datetime.date.today()
date.month
# Out:
# 6

# %%
class iters:
    def __init__(self,user,username):
        self.user = user
        self.username = username

class user:
    def __init__(self,fname):
        self.fname = fname

# %%
user1 = user("aviral")
iter1 = iters(user1,20225017)

# %%
i = iter1

# %%
emailId = ".".join((i.user.fname,str(i.username)))+"@mnnit.ac.in"

# %%
emailId
# Out:
# 'aviral.20225017@mnnit.ac.in'
