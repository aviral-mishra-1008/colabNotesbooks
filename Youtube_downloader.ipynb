# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.6 MB/s eta 0:00:00
# ...

# %%
Link = "https://youtu.be/ERRAurwpfVw?si=K6vWX8rsfQf_fGp6"

# %%
# !yt-dlp -f 18 https://youtube.com/shorts/D-HuN4U3LEE?si=7MuicAOvbG9l4YMp
# Out:
# [youtube] Extracting URL: https://youtube.com/shorts/D-HuN4U3LEE?si=7MuicAOvbG9l4YMp
# [youtube] D-HuN4U3LEE: Downloading webpage
# [youtube] D-HuN4U3LEE: Downloading ios player API JSON
# [youtube] D-HuN4U3LEE: Downloading player dee49cfa
# [youtube] D-HuN4U3LEE: Downloading m3u8 information
# [info] D-HuN4U3LEE: Downloading 1 format(s): 18
# [download] Destination: NEET 2024 PAPER LEAK ON TELEGRAM CHANNEL NTA BIG SCAM #ntabigscam#neet2024##neet#scam#shorts [D-HuN4U3LEE].mp4
# [download] 100% of    3.59MiB in 00:00:01 at 3.52MiB/s

# %%
# !apt-get install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
from spleeter.separator import Separator

# Define the audio file path
audio_file = 'Ankita2.m4a'

# Initialize Spleeter separator
separator = Separator('spleeter:2stems')

# Perform separation
separator.separate_to_file(audio_file, 'output/', codec='m4a')
# Out:
# INFO:spleeter:File output/Ankita2/accompaniment.m4a written succesfully
# INFO:spleeter:File output/Ankita2/accompaniment.m4a written succesfully
# INFO:spleeter:File output/Ankita2/vocals.m4a written succesfully
# INFO:spleeter:File output/Ankita2/vocals.m4a written succesfully

# %%
# !ffmpeg -i "/content/DOORIYAN - Full Audio Song - Love Aaj Kal ｜ Saif Ali Khan ｜ Mohit Chauhan ｜ Pritam [7z3YeFqd7xQ].m4a" "my.mp3"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from pydub import AudioSegment

# Define the input and output file paths
input_file = "/content/output/Ankita2/accompaniment.m4a"
output_file = "ankita_sawarLoon.mp3"

# Load the M4A file
audio = AudioSegment.from_file(input_file, format="m4a")

# Export the audio as MP3
audio.export(output_file, format="mp3")
# Out:
# <_io.BufferedRandom name='ankita_sawarLoon.mp3'>
