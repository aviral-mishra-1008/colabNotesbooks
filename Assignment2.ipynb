# %%
#Question 1
def fib(n):
  if n<=1:
     return n
  else :
    return fib(n-1) + fib(n-2)

# %%
#Question 2
s = input("Please enter the string: ")
s[::-1]
# Out:
# Please enter the string: I am Indian
# 'naidnI ma I'

# %%
#Question 3
with open('__FILEPATH__') as file:
