# %%
#We need states and transition probabilities to create the markov chain, the words can be states
#We need to determine what's the probability which word comes next after the current word
#We create a bag of word and then calculate the probabilities by dividing the number of words times a word came after the previous word in the state transition diagram by the number of outgoing
#Obviously over a large enough dataset some wrods will have higher probabilities of following an existing word
#This way we can generate a whole story using a set of similar stories

# %%
import numpy as np
import pandas as pd
import os
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import random
import pickle

# %%
#Fetch Dataset
import gdown
file_id = '1IgllT89j3j0_pkp4xtcadRitk2Faq9N6'
output_file = 'sciFi.zip'

gdown.download(f'https://drive.google.com/uc?id={file_id}', output_file, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1IgllT89j3j0_pkp4xtcadRitk2Faq9N6
# From (redirected): https://drive.google.com/uc?id=1IgllT89j3j0_pkp4xtcadRitk2Faq9N6&confirm=t&uuid=7b569ed7-79c7-47af-8abc-11ab8b9c0b23
# To: /content/sciFi.zip
# 100%|██████████| 58.4M/58.4M [00:01<00:00, 32.6MB/s]
# 'sciFi.zip'

# %%
# !unzip sciFi.zip
# Out:
# Archive:  sciFi.zip
#   inflating: internet_archive_scifi_v3.txt

# %%
txt = []
path = '/content/internet_archive_scifi_v3.txt'
with open(path) as f:
  for line in f:
    line = line.strip()
    if line=='----':break
    if line!='':
      txt.append(line)

print(len(line))
# Out:
# 149326360

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
cleaned_txt = []
for line in txt:
  line = line.lower()
  line = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-\\]", "", line)
  tokens = word_tokenize(line)
  words = [word for word in tokens if word.isalpha()]
  cleaned_txt+=words

print(len(cleaned_txt))
# Out:
# 26154071

# %%
def make_markov_model(cleaned_stories, n_gram=2):
    markov_model = {}
    for i in range(len(cleaned_stories)-n_gram-1):
        curr_state, next_state = "", ""
        for j in range(n_gram):
            curr_state += cleaned_stories[i+j] + " "
            next_state += cleaned_stories[i+j+n_gram] + " "
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
        if curr_state not in markov_model:
            markov_model[curr_state] = {}
            markov_model[curr_state][next_state] = 1
        else:
            if next_state in markov_model[curr_state]:
                markov_model[curr_state][next_state] += 1
            else:
                markov_model[curr_state][next_state] = 1

    # calculating transition probabilities
    for curr_state, transition in markov_model.items():
        total = sum(transition.values())
        for state, count in transition.items():
            markov_model[curr_state][state] = count/total

    return markov_model

# %%
markov_model = make_markov_model(cleaned_txt)

# %%
print("number of states = ", len(markov_model.keys()))
# Out:
# number of states =  4897107

# %%
def generate_story(markov_model, limit=100, start='my god'):
    n = 0
    curr_state = start
    next_state = None
    story = ""
    story+=curr_state+" "
    while n<limit:
        next_state = random.choices(list(markov_model[curr_state].keys()),
                                    list(markov_model[curr_state].values()))

        curr_state = next_state[0]
        story+=curr_state+" "
        n+=1
    return story

# %%
beginWith = input("Enter a word: ")
# Out:
# Enter a word: work

# %%
keys = list(markov_model.keys())
possibles = []
for i in keys:
  if beginWith in i:
    print(i)
    possibles.append(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# duenna work
# workers love
# works good
# workers was
# as workmen
# workmen in
# see workmen
# dozen workmen
# through workmen
# overworking and
# overworked you
# workers furiously
# leather worker
# worker past
# work successfully
# working left
# fireworks pinwheel
# machines worked
# worker five
# costs worked
# slix works
# works seemed
# paperwork would
# race working
# working sity
# work hauling
# nothing working
# worked behind
# perhaps working
# work garrick
# roosenburg working
# work practically
# was stonework
# stonework gargoyles
# gravediggers work
# vernes work
# screens worked
# workbenches were
# workbench in
# earthman worked
# working credo
# workings marner
# works plorvash
# workable then
# than guesswork
# guesswork in
# maintenance workshops
# workshops clinics
# workshop illuminated
# for brainwork
# brainwork hell
# table working
# working meticulously
# giant patchwork
# patchwork windows
# work impossible
# music fireworks
# fireworks firewater
# circus work
# finish working
# work pub
# ancestors worked
# worked happy
# haunting works
# scientific workers
# two coworkers
# coworkers as
# corner working
# oudemans work
# work commander
# working someone
# warp work
# work milly
# working will
# fictional work
# fireworks inside
# disaster work
# paperwork but
# work boys
# worked imtil
# clockwork salaam
# work mcintosh
# ferry work
# work time
# travel work
# train works
# work snader
# work sut
# work license
# either work
# comes workward
# workward in
# along working
# work steal
# loaf work
# workers related
# guards work
# jail worked
# mechanic work
# workshops that
# work cadena
# serum works
# milbun worked
# some workmen
# workmen nearby
# monotonous work
# laws working
# crazy guesswork
# guesswork was
# brickwork clutching
# hens bridgework
# bridgework but
# naturally metalworkers
# metalworkers and
# since metalworking
# metalworking was
# definitely work
# color woodwork
# woodwork color
# gently worked
# better workmanship
# workmanship than
# the classwork
# classwork during
# work swept
# exploration work
# tricky work
# merely guesswork
# guesswork yes
# worked liberately
# meaning work
# known work
# work farnsworths
# desired worked
# directed work
# work tables
# meads work
# idea network
# network hours
# a workhorse
# workhorse charting
# miniature fireworks
# fireworks let
# gland work
# work sky
# grimly working
# simple workable
# workable foolproof
# the basketwork
# work mooney
# work memorizing
# works especially
# workshop how
# hundred workers
# additional working
# working surface
# yard worker
# worker lets
# brain work
# or works
# works around
# slowly work
# jimmy work
# ben worked
# faddy work
# similar guesswork
# guesswork on
# handiwork no
# hole works
# persons working
# worked sanity
# careful workmanship
# workmanship only
# contact work
# artists worked
# diligent work
# workshop floor
# workshop she
# workshop any
# workshop they
# workshop why
# work box
# art works
# turtaned workers
# new networks
# working dropped
# whos working
# works large
# unholy work
# work torrek
# cable working
# photographic work
# tombaughs work
# prosthetic work
# inferior work
# work sampson
# defective work
# bad work
# work tentacles
# other framework
# longest works
# works however
# similar works
# work beatty
# work frantic
# damascene work
# work atout
# sniffle worked
# service workers
# workers our
# relations work
# relations worked
# teamwork take
# upsetting working
# embassy work
# impulse works
# itinerant worker
# work problem
# murchison worked
# teamwork at
# work everythingll
# work bloated
# pencils worked
# worked frenziedly
# work anderson
# groundwork is
# work whittling
# credible workmanlike
# workmanlike and
# work sample
# projectors work
# nobody worked
# worked except
# martins work
# work shown
# work lacked
# works two
# improvement work
# adults working
# network so
# rework the
# elses work
# working let
# work blum
# work lots
# harry worked
# foundation work
# standard work
# gesners work
# parks fireworks
# fireworks drinking
# greasy worked
# work yelling
# worked slicker
# since work
# work tropile
# works tropile
# complicate work
# work ultimate
# work lend
# zoological works
# fine worker
# robocommunications network
# two waterworks
# waterworks this
# by clockwork
# clockwork same
# red working
# vacation working
# distributors work
# anyone worked
# why work
# bother working
# works adventures
# work extinct
# innisons workshop
# network dont
# pyramid network
# pyramids network
# neuronic network
# a workmanlike
# popular work
# works glassware
# my glassworks
# glassworks but
# work faithfully
# robots work
# work lay
# standard works
# uh workload
# workload of
# easys work
# suzukis work
# perfect work
# work robot
# sizable work
# presses works
# and rework
# rework and
# hard workaday
# workaday facts
# work consisted
# work belongs
# kid working
# working summers
# ears working
# talkbacks work
# work firing
# in network
# network communications
# height works
# honest workmanship
# work homer
# the ironwork
# ironwork even
# rule work
# worked ane
# footwork for
# mt work
# jobs working
# works dropped
# working id
# working listen
# cleveland workmanlike
# workmanlike sequel
# workmen have
# worked lived
# skarn worked
# honored work
# work mechanically
# work pictures
# workbench farnsworth
# worked bravely
# beacons works
# and workouts
# workouts in
# before worked
# working eyes
# workers songs
# strike work
# chubby workers
# belphins worked
# worked ludovick
# belphins work
# coordinate network
# work ludovick
# work love
# crewmans work
# patrol work
# consulate work
# workers below
# extra workers
# workers coming
# ten workmen
# workmen competing
# working more
# wrongs work
# change work
# russians working
# blowing working
# working changes
# frantic patchwork
# patchwork last
# establish working
# working relationships
# work hp
# will working
# work horses
# him workings
# workings hard
# working us
# work dad
# set works
# guys working
# guesswork by
# defroster working
# federation worked
# wonderful workings
# aide working
# entertainers work
# working part
# this goldwork
# goldwork itd
# works bigger
# ultimate working
# a guesswork
# guesswork miracle
# using patchwork
# patchwork tactics
# deliberately working
# working adjustments
# working telepathy
# entirely working
# of clockwork
# clockwork it
# work grew
# filled workers
# workers everywhere
# work eight
# day work
# work exes
# beeri working
# most workers
# steel latticework
# frantic guesswork
# works include
# minor works
# arresting works
# work catching
# magnetic worktable
# work myra
# work psychological
# working collision
# work save
# unfinished work
# beats working
# working soundlessly
# longest work
# ingenious rework
# rework of
# workshop class
# tacled hardworking
# hardworking young
# worked beside
# generator working
# assigned work
# perceveral worked
# moles worked
# carefully working
# satellites work
# work describes
# anyone working
# somebody working
# meitners work
# out worked
# working girls
# powder worked
# working boys
# work warning
# work corder
# organized work
# work concerned
# passably workmanlike
# creative workings
# presentday worker
# your workmen
# workmen ever
# by works
# rapidly working
# work testing
# worked beading
# work roykin
# prisoners worked
# work halfs
# perhaps worked
# short worked
# monitor worked
# restaurant workers
# workers re
# work fighting
# completed working
# working smock
# works miss
# any guesswork
# guesswork into
# neat footwork
# once worker
# want work
# no framework
# interminably working
# work melhill
# work maintenance
# employers work
# network slave
# work increase
# networks an
# spider working
# away working
# working bn
# strictly work
# espionage networks
# inverted rework
# hillbilly works
# lighter works
# works inc
# working think
# sections work
# thisi work
# factor worked
# culture workable
# theyd work
# theoretical works
# technical works
# work merely
# havei worked
# pay work
# work short
# fresh rework
# workable materials
# work maine
# earlier works
# decay work
# work needs
# rough workmans
# works going
# work mars
# work charlie
# groundwork was
# worked crompton
# work crompton
# stack worked
# work overseeing
# us workers
# workers cost
# worked stack
# unworkable reforming
# uncomfortable work
# the workingman
# workingman everybody
# loren worked
# work ully
# openly work
# fine scrollwork
# bahamas work
# work boats
# artistic work
# working fluctuating
# learned work
# work states
# closerange work
# work count
# work lying
# laboratories worked
# works effectively
# work another
# seclusion working
# entire works
# device work
# even working
# harder work
# work squezing
# networks give
# networks said
# worked drinking
# catholic workers
# workers movement
# am workmanlike
# sanitation work
# certainly worked
# worked miracles
# woodwork it
# overhanging network
# perception worked
# workers didnt
# artificial workers
# serving work
# flimsy framework
# framework osborne
# research working
# gray workshirt
# workshirt was
# twoyear work
# arnie working
# work coaxing
# zombie network
# out work
# work blaine
# parapet work
# of workout
# pohls workshop
# worked surprised
# obviously unworkable
# unworkable now
# connections work
# desperate work
# work brings
# work last
# work serum
# works professor
# works drink
# commendable work
# worked dropped
# work human
# commands workers
# workers lined
# work brabant
# fine lacework
# gormen worked
# the webwork
# webwork chair
# webwork chairs
# working believe
# hibsens webwork
# webwork seat
# work thatll
# commence work
# work draw
# preservationist work
# artist working
# dons work
# naturally working
# stone framework
# working tik
# overwork in
# work followed
# her works
# work shed
# shakespeares works
# works werent
# times working
# joan worked
# evenings working
# tactic worked
# opal working
# optical worker
# worker designed
# working wonders
# theory works
# worked ai
# working areas
# indentured worker
# worked impossible
# varied works
# works some
# works should
# particular work
# work dorothy
# working sleeping
# workable sort
# shes workin
# workin it
# strategy worked
# worker per
# individual worker
# one worker
# workers chanced
# extrapolative work
# study working
# fastening worked
# working okay
# hesketh worked
# processing works
# works circled
# shredded worked
# machinery work
# worked while
# charms work
# work sutherland
# worked sometimes
# barbara works
# works suppose
# work ron
# works outside
# legal fireworks
# fireworks rex
# in schoolwork
# homework in
# work tt
# wood worked
# working weekday
# woodwork not
# themes work
# such working
# working material
# network fighting
# the spadework
# spadework in
# network time
# subconscious working
# homework there
# snug work
# ketch working
# quedak framework
# framework you
# working drake
# working cable
# work cursing
# drake working
# working twelve
# this housework
# housework thats
# invigorating work
# kilners work
# housework kiss
# icicle works
# works closed
# work teleporting
# works folded
# works dickon
# works knew
# lighter work
# political workers
# workers ignoring
# four workers
# works hurt
# icicicle works
# under worked
# work shoes
# klevity worked
# stoop working
# faithful worker
# work hell
# workers henry
# sort work
# possibly work
# work ii
# working heard
# brutal work
# work denham
# servants working
# toaster worked
# tired working
# her footwork
# footwork was
# foresail works
# mostly work
# working somebody
# apparatus worked
# collector works
# works ill
# converter worked
# truck working
# psychiatrist work
# indubitably work
# another network
# network alleged
# the latticework
# striptease working
# work dictator
# and homework
# homework machine
# empirical work
# average workman
# workman therefore
# hardware works
# work coldly
# work someone
# worked furthermore
# working desk
# clockwork man
# pills worked
# working balance
# good workmanship
# workmanship the
# english fireworks
# fireworks maker
# work robert
# most work
# decontamination worked
# working hand
# working dirt
# workers mouth
# typical workman
# workman as
# watching workmen
# workmen drilling
# citizens work
# subjects working
# works among
# putterer working
# homework again
# now works
# technologist working
# the firework
# firework manufacturers
# one workday
# workday morning
# workout dont
# white woodwork
# woodwork black
# late working
# working lineman
# large work
# horbigers work
# work may
# protector work
# body working
# worked naturally
# such masterworks
# masterworks as
# pathetic work
# work hacked
# work bunched
# provided work
# half worked
# carl worked
# student working
# work shared
# works roger
# work roger
# working checked
# networks shared
# networks programs
# working locille
# bitterwater working
# working harness
# busy work
# working crossword
# its guesswork
# guesswork dorsey
# work kimball
# em working
# working tell
# works will
# purnie worked
# careful work
# work quoting
# galileis works
# works believe
# enormous network
# timmy worked
# greels working
# s working
# work designed
# concise work
# work requiring
# einstein working
# workers blasting
# grant workers
# workers rebuilt
# acceptable work
# staghorn worked
# work destroyed
# works accusations
# workhorse word
# worked seeing
# gigantic fireworks
# worked id
# officers worked
# hurrying workers
# projected working
# work ab
# work beth
# are masterworks
# masterworks take
# star work
# work halacy
# workhorse freighter
# skeleton framework
# framework rising
# communicators work
# work johnny
# worked entirely
# full works
# germs work
# stimulating work
# accent work
# work clarey
# go work
# work wrote
# findeisens works
# the waterworks
# waterworks and
# fireworks could
# carter worked
# work carter
# coblentzs work
# famous works
# stabilizer working
# working locate
# flaunted millwork
# millwork and
# stabilizers working
# gates worked
# planeteers worked
# first artwork
# work foley
# modern work
# work therell
# advanced works
# bomb work
# blind workers
# susie working
# telephathy worked
# work gumpy
# dock workers
# old basketwork
# basketwork fishing
# studiously working
# happy worker
# worker my
# workers is
# worker oh
# work composing
# panel work
# working north
# work derek
# harder working
# americans working
# working daily
# migratory workers
# work sari
# remember working
# ah works
# works back
# work fer
# working has
# great workers
# patrons worked
# schmitzs work
# work above
# detective working
# hitton worked
# working regular
# work sometime
# works subscribe
# adecal workups
# workups on
# left workups
# cautiously working
# door worked
# framework at
# framework holding
# framework back
# framework expanding
# clockwork blaken
# yours works
# housework partook
# hands working
# work exactly
# working compromise
# working majority
# zells work
# work thissell
# excellent works
# works kershaul
# works zealously
# isolated worker
# worker has
# wheels worked
# diode works
# salt works
# perception work
# had bridgework
# bridgework i
# frantic work
# work trenton
# work camp
# castle worked
# is workshop
# worked always
# dam work
# bring worker
# worker friends
# waist working
# jerry worked
# work jerry
# precipitrons working
# band worked
# us workcrazy
# workcrazy actually
# work rumpleman
# rigid framework
# lie worked
# fifty workmen
# workmen marched
# easiest work
# blahrog worked
# dental work
# networks sollenars
# and network
# network relay
# clumsily worked
# immortality works
# works burr
# here work
# high work
# work hood
# ample working
# worked afterwards
# work congregations
# worked mazda
# work buttons
# wonderful fireworks
# fireworks he
# kind works
# row worked
# eh work
# scout work
# work recreation
# worked cautiously
# made worked
# aristotles works
# tired work
# work flowed
# wiry network
# i workedwith
# workedwith donald
# working arrangements
# boyfriend worked
# council working
# working proxy
# clockwork going
# largely patchwork
# patchwork i
# work gobbling
# clerical workers
# mechanism works
# clockwork a
# been clockwork
# clockwork he
# worker claire
# work dawes
# crewmen worked
# six work
# work gangs
# stockade work
# permospray work
# swift work
# worked ripping
# imagination worked
# take teamwork
# teamwork real
# real teamwork
# teamwork ill
# working these
# truly working
# worked exactly
# workshop then
# carcolo worked
# arms worked
# working feebly
# workshop rphe
# workshop lead
# workshop hesitated
# of workshop
# tiered workshop
# workshop which
# his workroom
# workroom his
# bloody work
# workroom the
# sacerdotes worked
# works maid
# work essential
# rococo work
# humanoids worked
# work capacity
# overwork us
# be overworked
# overworked our
# work barnhart
# workings in
# work although
# caul works
# works swallows
# five works
# works their
# revolutionary work
# cheeks worked
# food works
# works six
# painted works
# cauls work
# nightmarish work
# gray work
# work thankee
# devious workings
# worked find
# write work
# daily work
# work cmell
# hedge working
# work fascinated
# work quite
# instrument works
# workers union
# diesel works
# worked yes
# possessed working
# working evil
# worked besides
# with workbenches
# workbenches and
# work vere
# are work
# worked im
# bimmies working
# recent works
# work waded
# thoroughly overworked
# overworked words
# lillys work
# framework vibrating
# naked framework
# framework appearing
# work emergencies
# workers youre
# theyll overwork
# overwork without
# workers magnetizing
# increasing worker
# solitary work
# perpetual work
# waterfront workers
# worked settled
# work professor
# work basically
# demonstrator work
# design works
# stiffeners work
# name works
# electrical workshop
# workshop came
# siberian work
# working models
# chandlers work
# worked getting
# coronets worked
# worker released
# himself worked
# execs working
# laboriously worked
# doubt worked
# friends working
# crucial work
# isnt work
# koitskas work
# working coronet
# emma works
# work touching
# hands work
# work emma
# find working
# journalistic work
# works understand
# a matwork
# matwork long
# framework right
# cooling worked
# historical work
# working reducing
# workmanship however
# sipi work
# enoch worked
# thubans work
# colored patchwork
# galactic network
# network might
# network all
# work enjoyed
# third workers
# workers district
# must rework
# the workhorses
# another workable
# meteorological work
# cameo works
# transmitter worked
# defenses worked
# works employing
# workman is
# worked half
# surgically worked
# work disaster
# motorized workgangs
# workgangs stood
# the workgangs
# workgangs rolled
# volumes working
# work permitted
# chain working
# bomb working
# guesswork the
# work raising
# brute work
# worked asked
# failure working
# old work
# work twisting
# workers placed
# college working
# network office
# course network
# network producers
# networks own
# networks star
# concept work
# mow working
# board working
# techniques working
# fist worked
# tentacled workmen
# magical work
# whatever work
# though works
# caught work
# working jaws
# slippery work
# painfully working
# figures working
# stroon work
# that overworked
# overworked phrase
# homework ill
# work public
# newspapermen work
# calhoun worked
# worked calhouns
# calhouns work
# those workhorse
# workhorse ships
# calhoun works
# work calhoun
# teehalt worked
# work disengaged
# iron works
# works olliphane
# with workers
# workers ducking
# worker perhaps
# work beyond
# working llewellyn
# entire network
# workman still
# workmen cease
# propaganda network
# graceful work
# true works
# dewforth worked
# of workspaces
# workspaces for
# worker hope
# among workers
# workers without
# experimentally working
# costumery work
# work witchcraft
# ricketty patchwork
# patchwork illusion
# state working
# working occupation
# mens work
# worker granted
# working dollars
# xxla working
# worker seated
# worker stumblingly
# know worked
# worker since
# worker interesting
# worker away
# worker get
# warning network
# network out
# mr worker
# worker there
# worker an
# worker others
# worker if
# worker thats
# worker today
# worker once
# networks good
# worker stop
# worker dont
# worker signs
# worker i
# worker drop
# work stoppage
# work merle
# workshop arithmetic
# work namely
# tristano work
# sarkoy worked
# but workinghours
# workinghours are
# skull worked
# worked incommensurable
# work mending
# sod worked
# the workwoman
# workwoman eleanor
# work talking
# his workwoman
# man workwoman
# an evilworker
# evilworker with
# vast networks
# monkey working
# your workwoman
# workwoman into
# defense works
# curve work
# open latticework
# telescopes working
# guesswork tjond
# worked iv
# analyzers worked
# work seems
# convenient working
# work performs
# surplus work
# words worked
# its bodywork
# bodywork a
# johnny worked
# germans worked
# germans working
# work carried
# sanger worked
# anagram works
# terribly hardworking
# hardworking he
# worked robson
# some metalworking
# metalworking tools
# yet paperwork
# workings out
# mary worked
# work ruined
# shrugged work
# work drink
# work vivana
# a quiltwork
# quiltwork of
# frenzied work
# work lined
# working much
# worked unaccountable
# weary work
# finger work
# work decisively
# my lifework
# lifework yet
# ago work
# working witch
# voluminous work
# schmerlings work
# work remembered
# workmen began
# year workers
# everything working
# reactions work
# t work
# his workmates
# workmates as
# works number
# robos worked
# worked switches
# working cadman
# asked working
# their scissorwork
# scissorwork outlines
# stomach worked
# tangled network
# ominous workings
# against work
# work cheerfully
# whom work
# his workmen
# three workmen
# workmen used
# workman had
# news network
# network representative
# network well
# work unasking
# my newswork
# newswork mostly
# network back
# padma worked
# network center
# sunlight worked
# honest working
# working making
# mustnt work
# erasure working
# work smirnov
# workers issued
# work smirnovs
# shadow work
# of dogwork
# dogwork to
# work max
# water network
# network spring
# reconstruct work
# work milt
# limited clearingwork
# clearingwork in
# lap working
# intricate workmanship
# workmanship by
# work backward
# working lines
# worked elections
# bigelow working
# effective work
# the scutwork
# scutwork left
# troubleshooter work
# smoothly working
# workers instead
# boys network
# network bribery
# works whats
# maybe work
# unmoved worked
# wafer works
# work xt
# nobler work
# development workshops
# workshops he
# another framework
# framework through
# working transmitter
# clearly works
# works interesting
# shoulder working
# throat work
# chines work
# she working
# niles work
# the workaday
# workaday uniform
# smooth working
# pencils working
# work legend
# hidden clockwork
# clockwork made
# zeiss works
# with lathework
# lathework that
# work odyssean
# generally work
# nearly worked
# pace working
# confidential work
# general working
# colgrave worked
# snarl working
# work nearby
# nervous working
# works custer
# ah worked
# worked tiborough
# be patchworked
# patchworked out
# great worker
# quickly work
# work great
# own works
# works unfortunately
# biological works
# individual work
# skilled work
# plans work
# intense work
# cquld work
# write works
# ladions work
# greatest works
# enduring works
# completed work
# madden work
# work neurothrills
# just paperwork
# paperwork waivers
# ordinary working
# working detective
# work mchonnery
# congenial working
# work unfulfilled
# works every
# works lets
# shooting works
# works slid
# car worked
# homework jim
# fine network
# worked listen
# belong work
# workload that
# chemist works
# precise work
# outstanding work
# heat working
# systems work
# work trapped
# muscle worked
# bickels handiwork
# handiwork all
# working prue
# properly working
# working robobrain
# working quietly
# shop working
# this framework
# framework bickel
# prudence working
# said works
# works primarily
# working tim
# overlap network
# network approximate
# work synergy
# unconscious networks
# possibly workable
# workable idea
# skeleton frameworks
# network at
# a gridwork
# gridwork of
# teamwork improves
# working professional
# meet working
# forrester working
# industrial workers
# into handworking
# handworking dogsweaty
# working angrily
# whod work
# not overwork
# overwork im
# im overworked
# overworked myself
# working girl
# telepaths working
# telepaths worked
# working steel
# gone work
# contraptions work
# something work
# worked across
# legs worked
# work forces
# worker decades
# work vending
# sandropoulos worked
# working passed
# worked each
# work paradoxically
# work wherever
# work acquiring
# shifting network
# much reworked
# reworked rock
# fungus working
# nphey worked
# colonists working
# working guide
# poor workmanship
# workmanship during
# work programming
# work towards
# icm workers
# workers said
# huh working
# where work
# bennet working
# noble work
# workbench along
# worked wordlessly
# espers worked
# timkin workers
# workers tinkling
# shift workers
# workers howled
# cease work
# burly workers
# workers tried
# reys work
# earliest work
# work differs
# deals work
# wpa worker
# work sweat
# homework was
# forresters homework
# homework could
# work whitlow
# work chuck
# working joymaker
# firstborn working
# works l
# appointed work
# work memories
# tricky footwork
# footwork over
# underpeople work
# work tphey
# workable diving
# currents worked
# operation worked
# surprise work
# salvage workers
# workers can
# homework still
# homework instead
# work martell
# worked abruptly
# commission workmen
# workmen through
# agents workmen
# reactor worked
# work instantly
# genetic work
# martell worked
# political workings
# work breakfast
# work weeding
# workers recruited
# sourdough working
# still workable
# workable spaceship
# machine work
# organic working
# idle workers
# workers cant
# subway workers
# a workforce
# workforce of
# work apron
# transceiver working
# overhead framework
# malicious work
# meks working
# is unworkable
# unworkable but
# work reserved
# homespun worked
# tile work
# toil worked
# up earthworks
# earthworks before
# the earthworks
# earthworks was
# earthworks after
# formerly worked
# worked four
# storytellers work
# apparently worked
# this unworkable
# unworkable monster
# unworkable world
# rrhe dogwork
# dogwork was
# workmen coming
# vorsters work
# workings the
# work kirby
# work lazarus
# vorsts work
# issue work
# worked myself
# work sos
# works cilence
# works jepson
# working hes
# juryrigged workshop
# obs work
# intuitive worker
# worker you
# works yeah
# ob work
# work stone
# work progresses
# workroom returned
# work swimmer
# ob working
# workroom macpreston
# workroom they
# exquisite workmanship
# workmanship it
# workers exploiters
# work vladimirov
# works try
# no workimr
# workimr occupation
# overworked impatience
# workers suppressing
# microphone working
# working doctor
# treatment worked
# works forever
# work timell
# in workman
# workman brown
# harvey worked
# workmen reading
# working tempo
# working nourse
# drugs working
# working towards
# works instead
# works produced
# mostly worked
# by network
# commercial work
# tissue working
# workaday technician
# work interesting
# work recently
# work vorst
# workout this
# fireworks factory
# close working
# first network
# network rights
# medical works
# anybodyd worked
# working occupied
# work areas
# working power
# gitlers working
# fongavaro worked
# of footwork
# footwork just
# works inconsequential
# skyway networks
# networks calapine
# shimmering networks
# work boumour
# candidate work
# work resembles
# work ontl
# oeenpadon working
# working honrsam
# trig homework
# homework according
# bank worked
# barge work
# myself worked
# lenka workmanship
# workmanship from
# workmanship gersen
# woodwork lacquered
# redpencil work
# work alfs
# vliose work
# work aiiats
# hos work
# work la
# kiras working
# working mind
# worked alioth
# other fireworks
# fireworks followed
# zealand working
# uncollected works
# dr clockwork
# work signed
# ever works
# scarcely work
# work stevens
# test worked
# worked somewhere
# pain worked
# worked briefly
# work ours
# test works
# work others
# overworked colonial
# work murphy
# work counter
# wooden work
# work chair
# homework on
# lifesystems working
# work fortunately
# airmakers works
# work question
# working journalist
# workshop surrounded
# prisoners working
# surviving work
# intricately worked
# work mischief
# stores workshops
# work intermediate
# work inorganic
# commune worker
# worker deceased
# chinese workers
# workers costume
# commune workers
# workers rags
# workers clothes
# esk outworks
# outworks a
# everyday work
# large overworked
# overworked lab
# worked otherwise
# work greek
# lever worked
# network pinedo
# pr work
# link works
# works widely
# work vaned
# working unhindered
# shells worked
# work epikt
# was overworked
# overworked when
# druids worked
# rockface working
# work chinking
# working terry
# building worked
# leather work
# work beads
# work chores
# overworked for
# him worked
# children working
# working rhythmically
# was handworking
# handworking the
# working strongly
# oval patchwork
# patchwork reconstruction
# workmen welding
# work incomplete
# tunnel worked
# burned working
# workman but
# alpha network
# work switchboard
# dayshift workers
# workers everyone
# pithead workings
# together work
# platos work
# work rumbled
# a workbot
# workbot to
# rare works
# alleged network
# miners work
# working strictly
# three works
# library work
# worked manually
# hormones worked
# worked r
# subsequent works
# empty work
# established working
# working sf
# harley work
# exhausted working
# undone homework
# integrated teamwork
# teamwork it
# footwork belonged
# understanding works
# framework written
# german worker
# rockets worked
# tracking network
# network with
# chance working
# june working
# reporters worked
# worked us
# red fretwork
# fretwork in
# forget work
# sheerest guesswork
# individuals working
# year work
# obediently work
# ducts worked
# working upward
# work olms
# work marie
# working myself
# working lots
# enough working
# concrete workings
# workings men
# work unobserved
# working praying
# global networks
# networks every
# masterful workmanship
# working malti
# sage works
# networks stopped
# network this
# guilds working
# scabs work
# networks with
# work c
# work tax
# working member
# work highly
# father works
# works holding
# bigger work
# included workouts
# workouts from
# muscles work
# work anerobically
# forces work
# average working
# boulders working
# needs work
# work candelas
# working clipped
# too worked
# dirty works
# work lehman
# zogbaum worked
# work preparatory
# too work
# bureaus work
# clockwork everything
# no network
# network coverage
# early works
# inches work
# french workers
# workers needless
# jomfri worked
# worked reached
# not workers
# workers builders
# topflight work
# seminal works
# new framework
# eventually worked
# maxwells work
# work raking
# times work
# worked simonson
# work maxwell
# handiwork behind
# work lengthy
# framework to
# joints worked
# prosthetic framework
# framework by
# worked ive
# collared workers
# couch working
# conscientious worker
# technological work
# working itillegally
# and fretwork
# worked tthe
# worked marvelous
# any works
# month working
# working disturbingly
# equipment works
# thats guesswork
# guesswork well
# work presently
# along unworkable
# unworkable linee
# old working
# worked checking
# workroom adjacent
# actors working
# stand working
# tke work
# mediocre work
# bleiler works
# work fneans
# his workmanship
# worked kis
# ter work
# pacifica network
# work earns
# hopefuls work
# work presented
# arts work
# work mid
# works zoroaster
# tkat works
# serious workers
# worker ske
# more worki
# worki free
# cassius working
# consciousness worked
# bellows worked
# food worked
# his gangwork
# gangwork he
# work site
# uncyborged workers
# workers energized
# work greater
# greater work
# eucumbene works
# whove worked
# immortal works
# them works
# works made
# shop work
# mysteries works
# workshops would
# worked noiselessly
# tke workmanship
# bronze grillwork
# grillwork slipped
# working lifetime
# giant network
# work eliminating
# land working
# ruined works
# actor working
# cyborgs working
# arms working
# underground work
# more workable
# workable i
# need worked
# cyborged workers
# workers miners
# rsterious work
# texan workingencampment
# workingencampment ven
# which workei
# workei well
# karmic works
# simple worker
# powered framework
# framework which
# strugatsky working
# club work
# work fnch
# work nations
# tee networks
# networks think
# workers poll
# such networks
# beautiful works
# working witb
# working ofi
# tkeir work
# idnk worked
# teeoretical work
# worked fought
# seeking works
# incoming work
# work suitably
# work coloring
# her workmates
# workmates baffled
# complicated wristwork
# wristwork in
# nancy worked
# work bins
# work witii
# perfect worked
# paperwork amongst
# klings working
# a workload
# workload hiat
# out patchwork
# patchwork people
# tee work
# work teey
# struction work
# communications networks
# comm networks
# tfie work
# worked promise
# notable work
# devised working
# working generally
# somnambulists work
# tic working
# work dimbulb
# working relay
# plotch working
# working instantly
# unit works
# working coveralls
# imitations work
# work location
# working suit
# under working
# end working
# working station
# without workers
# sciencefiction works
# work break
# works technician
# suspended work
# safe work
# work ceased
# deserved working
# solid stonework
# stonework that
# emergency work
# working true
# workers fifty
# eckolocator working
# exercise worked
# flipper works
# natures work
# involve reworking
# reworking everything
# framework okay
# working column
# clock works
# weird framework
# framework in
# work maggie
# porpoise worked
# works aldiss
# work solely
# toy works
# work activities
# little footwork
# janitor work
# sometimes work
# teams working
# sciences worked
# worked much
# worked problem
# familiar work
# students working
# details work
# manipulation worked
# working office
# work ebert
# bad worked
# and sudwork
# sudwork with
# silverbergs work
# work used
# its overworked
# sanitation workers
# nonsense work
# work bureaucratic
# spy working
# connearney worked
# lagoratories workrooms
# workrooms equipment
# main workroom
# workroom f
# workbench flashing
# overwork they
# work rassmussen
# steks work
# physicists workroom
# workroom as
# work driving
# where masterworks
# masterworks have
# guessed worked
# worked madly
# highsteel workers
# now worked
# work whistled
# ink worked
# probably unworkable
# unworkable fountain
# works truly
# work limply
# paperwork these
# shje worked
# owen work
# working owen
# working honest
# moving working
# work sturgeon
# dedicated hardworking
# hardworking learned
# framework delany
# sexless grillwork
# works insidiously
# grillwork and
# works qlmayne
# taxing work
# surgeons worked
# framework along
# cease working
# onsott working
# working palemouthed
# work keneally
# their network
# vw works
# works brown
# work engram
# shipmind work
# of headwork
# headwork in
# radinae worked
# design nonworking
# nonworking engines
# agreement worked
# botanical work
# spanish ironwork
# ironwork and
# steel grillwork
# grillwork which
# ceiling worked
# sliding grillwork
# grillwork door
# leningrad working
# intensely workable
# workable situation
# gods handiwork
# handiwork undisturbed
# unusual workthe
# workthe process
# kis work
# work mixing
# milford workshop
# workshop sessions
# of metalworkers
# lads work
# her needlework
# needlework he
# such handiwork
# work record
# worked ectc
# work displacing
# murv worked
# space network
# postgraduate work
# ains work
# work stubborn
# stiu work
# work witb
# geodesics work
# work henceforth
# work rather
# absorbing work
# yur work
# working witfi
# worked chesters
# work feinberg
# armed working
# working teeir
# are workers
# obedient workers
# workers i
# many workers
# workers ten
# workers job
# slavery work
# workers armed
# worker control
# work lead
# working did
# workers only
# open working
# lights worked
# working interdependently
# elbow working
# any network
# grayle worked
# area work
# fiction works
# our caseworkers
# caseworkers will
# workers visit
# the caseworkers
# caseworkers from
# loft caseworkers
# caseworkers in
# work oblivious
# of caseworkers
# caseworkers gaggle
# verbaceous caseworkers
# caseworkers into
# different workers
# three caseworkers
# single caseworker
# caseworker as
# the caseworker
# caseworker who
# presently caseworkers
# caseworkers trickled
# kert worked
# twig worked
# ritter worked
# work hardly
# worked witli
# work assignments
# waterworks so
# work bens
# valier worked
# a wellworking
# wellworking rocket
# radiotelevision network
# network an
# reconstitution works
# irrigation works
# me works
# touched brickwork
# brickwork he
# work warden
# polished brightwork
# brightwork welcome
# glass working
# weintraub worked
# working charge
# work dooley
# work chani
# designs worked
# floor worked
# tarot worked
# a basketwork
# irregular webwork
# webwork it
# webwork was
# golgi network
# gross workings
# work onyway
# work begim
# braun worked
# working watch
# fabulous work
# in teamwork
# teamwork our
# lemacs worktable
# worktable bounced
# in spacework
# spacework for
# as worked
# hypnotism worked
# worked old
# gingerly worked
# specter artwork
# work lagrad
# work elsewhere
# soil work
# hard workers
# workers go
# fish worked
# identity framework
# observational work
# work dav
# welfare work
# work nonetheless
# smallish work
# work braxn
# networks a
# network funny
# unions working
# intelligent webworks
# webworks of
# clerks worked
# social network
# gotten worked
# plasmeld grillwork
# his grillwork
# grillwork he
# balconys grillwork
# grillwork paul
# ixian handiwork
# handiwork pneumatic
# handiwork through
# ruin networks
# working prototype
# willys work
# was woodworking
# woodworking she
# cotton workgloves
# workgloves a
# signed work
# work order
# work hope
# elder workers
# workers frustration
# familiar workbench
# workbench regarding
# fremen work
# clob works
# pohl works
# works gems
# grinned works
# works faster
# intense workers
# work fenthree
# devil working
# satellite work
# worked time
# on workable
# workable engineering
# ripe grainwork
# grainwork work
# working dans
# tinkers work
# a nonworker
# nonworker eating
# titrator working
# working dag
# workout moon
# worked wish
# toothpick worked
# workshop moses
# by fireworks
# artwork itself
# humble workman
# workman and
# work totally
# horn worked
# room workshop
# motto work
# stroboscopic fireworks
# the groundworks
# groundworks done
# work playing
# work saying
# any fireworks
# fireworks are
# workers less
# workers dared
# the underworkers
# underworkers will
# caste working
# working shaara
# turning workers
# workers lifted
# workers their
# workers approached
# caste worker
# workers talked
# machines workers
# workers flew
# workers scurrying
# workers hung
# accoutrements workers
# workers no
# worker whose
# breed workers
# workers exist
# workers spooky
# work grimes
# working mandibles
# work wednesday
# work allotments
# work level
# work according
# and illworking
# illworking and
# book works
# intricate latticework
# latticework the
# death handiwork
# handiwork observed
# cosmic fireworks
# cats worked
# work filled
# quite working
# works nowadays
# works scott
# works evan
# cradlelike framework
# framework overlooking
# change worked
# memorable work
# a fretwork
# workman make
# work carmichael
# ant workers
# workers floating
# allison worked
# work rest
# working occasionally
# lanky coworker
# coworker with
# paladin working
# work crews
# androids working
# workmen his
# an openwork
# openwork lace
# work extraordinary
# a latticework
# latticework radio
# worked shall
# navigational network
# equipment working
# your workshops
# workshops will
# mavis working
# workshops a
# workshop or
# surgical work
# worked ouf
# homework today
# invisible webwork
# webwork backdrop
# me worked
# work programs
# halt work
# intricate webwork
# work kafka
# androids work
# work constantly
# android workers
# crews work
# laborers work
# work smoothly
# alternate work
# working methodically
# recalibration work
# been work
# small working
# workmen betas
# android working
# work manuel
# workers stood
# outbound workers
# work coding
# i workable
# latest work
# remodeling work
# algae worker
# husband works
# unfathomable workings
# workings beyond
# work lights
# work follow
# workmen slide
# airborne webwork
# subterranean workshop
# workshop down
# accelerating work
# work thus
# decent hardworking
# hardworking alpha
# grammar work
# tower work
# the openwork
# openwork blouse
# structural framework
# framework throughout
# working revealingly
# work halted
# with workmen
# workmen marooned
# trapped workmen
# workmen then
# soleri working
# work micaela
# erotic works
# works jason
# work interface
# later working
# and latticework
# arizona groundwork
# proper framework
# clearly unworkable
# unworkable it
# local workmen
# workmen talk
# the workable
# workable delusion
# homework you
# have homework
# homework dont
# moore working
# worker even
# working shed
# works theyre
# psychiatrist working
# secretarial work
# overwork a
# glass worked
# worked patiently
# work originally
# work satvje
# wares workbench
# workbench furthermore
# workbench it
# situation works
# treads worked
# invention working
# balloon works
# queer network
# working powerful
# what trickwork
# trickwork to
# girls work
# always workedit
# workedit always
# worked today
# rail works
# works baffling
# patchwork your
# memory works
# works except
# salomon works
# valuable works
# overwork him
# difficult work
# webwork cradle
# a hatchwork
# hatchwork of
# work whenever
# workers don
# workers helmet
# electrode work
# working porter
# editor working
# workmen driving
# workman said
# workers hurtled
# workers crowded
# jewelers working
# worked construction
# handiwork without
# efficient workings
# paul working
# body worked
# foundations work
# what worked
# viewpoint works
# hotel workers
# workers approved
# damaged work
# project worked
# brief workouts
# works jemand
# small works
# works eg
# soft woodwork
# woodwork on
# work map
# large workmans
# workmans hands
# work intuitively
# work casually
# working folk
# work duty
# the makework
# makework in
# involve working
# working also
# joe working
# wont overwork
# working uh
# work annamaria
# working guild
# work safe
# hester work
# workers soldiers
# mass work
# work places
# braden worked
# working mary
# we rework
# elan workers
# viruses work
# rework it
# bog work
# work fortifying
# works id
# do homework
# students homework
# homework nor
# workout when
# officer worked
# worked desperately
# worked pumping
# once working
# census work
# arsenal work
# insane working
# four worked
# squinted worked
# ta work
# h work
# work pulling
# his coworker
# coworker you
# working laboratories
# prevailed workmen
# work lou
# black workers
# allow workers
# workers through
# lines worker
# moving workers
# workers provided
# no worker
# tasks work
# deserted work
# halting work
# the nonworkers
# nonworkers calling
# few workers
# workers arsenon
# work edith
# habits working
# wore work
# worker maybe
# distant working
# worked damned
# works gone
# works during
# convincingly worked
# reynolds work
# work gordon
# paperwork as
# com networks
# networks should
# transmat working
# lous work
# lou worked
# cluttered laboratoryworkroom
# laboratoryworkroom he
# workbench no
# anton working
# biochemists working
# working despite
# yesterdays work
# work lost
# biochemists work
# clockwork yeah
# hungry workers
# smile worked
# calvins work
# hectic work
# work calculations
# recyclers work
# unfinished works
# lofty breastwork
# breastwork of
# old woodwork
# hardworking men
# darkroom work
# work nobodys
# youth working
# program worked
# place work
# unproductive work
# prose workings
# workings that
# work delivers
# fields worked
# work randys
# good hardworking
# hardworking types
# work related
# department worked
# work tin
# paperwork connected
# ed worked
# work somebody
# worked ft
# works please
# males work
# be overwork
# overwork no
# drunken worker
# worker killed
# footwork is
# its overwork
# overwork pure
# bastards work
# workers ill
# barrows working
# simple overwork
# overwork looking
# but overwork
# overwork i
# company work
# workaday grind
# sweatshop working
# working submit
# paperwork i
# responsible workers
# worked anybody
# work lasvogel
# stress work
# work stress
# work pressure
# spat work
# that homework
# homework to
# works incredible
# grid work
# work harvey
# programing worked
# work often
# liaison work
# oakes worked
# work sarah
# bigelow worked
# the workmanlike
# workmanlike to
# ornate ironwork
# ironwork balconies
# workers as
# work poorly
# his workshops
# working project
# normal workings
# work goeffrey
# alchemists workshoplot
# workshoplot of
# work street
# work digging
# work macdonald
# enclave working
# working flirting
# hilt worked
# the workhorse
# workhorse hese
# work end
# working good
# working even
# networks hah
# working barbara
# last working
# working line
# broadcast network
# network radios
# way work
# work judy
# workroom mother
# workroom all
# workroom everyone
# workroom tim
# ur work
# writing workshop
# sf workshop
# tulane workshop
# workshop will
# workshop department
# sid works
# works cant
# intermediate works
# works left
# work sellie
# porque working
# solo work
# fireworks about
# workout so
# work lies
# companies working
# work lucifer
# newcomers work
# navigators work
# her upperworks
# upperworks and
# works harrell
# working chart
# century work
# veering working
# working gradually
# working iron
# brightwork it
# selfpreservation worked
# remaining overworked
# overworked patrols
# kyrie worked
# work guy
# cafeteria worker
# worked lying
# machinery works
# mesa worked
# worked twice
# workers grim
# hastily worked
# worked screen
# story work
# slazeck worked
# work kiliath
# rarely work
# pete worked
# nice workout
# workout before
# telepathic network
# difficulty work
# repetitive work
# equations work
# workers fishermen
# church work
# public networks
# framework set
# idea work
# our framework
# from frameworks
# frameworks hysteresis
# frameworks gregory
# framework actually
# old frameworks
# frameworks centuries
# framework cogsworth
# narrow framework
# relay works
# literate works
# editorial workers
# work worthy
# action workable
# workable if
# jewel works
# beacon working
# working yes
# handiwork what
# workers servants
# hardworking boy
# makers worksheets
# worksheets and
# inspection paperwork
# paperwork we
# warm work
# refresher workmg
# workmg the
# wet work
# shipyards working
# nebish work
# workers each
# light worked
# working ode
# clones working
# workmen loaded
# workout soon
# work north
# worked casually
# dan worked
# worked look
# voyage work
# woodwork she
# unburdened work
# firework in
# working wings
# works cryptograms
# white worked
# solid working
# workshop his
# workshops scraps
# bright working
# cgniplete workshop
# the unworkable
# unworkable concept
# workings not
# work begging
# transfer working
# hurried work
# earths work
# working swimmingly
# overworking havent
# myself work
# network instability
# work choosing
# working solar
# neodynamite working
# working awkwardly
# work jims
# mercer worked
# work mathewson
# order working
# working clockwise
# equally overworked
# overworked water
# prescott worked
# worker priest
# handiwork six
# work reassuring
# working society
# wickerwork basket
# work blind
# working room
# lamonts work
# worked actually
# ben work
# lunar workers
# earth workers
# work effectively
# work earthmen
# plastic worked
# admired needlework
# needlework showed
# tapes work
# plain workaday
# workaday reasons
# work elegantly
# harlie working
# working yet
# nonessential work
# work ie
# company network
# work harlie
# workable foreign
# data network
# coding working
# working data
# network handled
# corporate paperwork
# paperwork functions
# langleys webwork
# webwork dish
# working premise
# works reveals
# the schoolwork
# schoolwork hopelessly
# kafkas work
# work selig
# called worked
# redhead working
# shepard works
# works groped
# worked faultlessly
# crackpots work
# work tavern
# canning workers
# worker laid
# workers during
# you workers
# jackson working
# network dropped
# workable reality
# worked surprisingly
# individual works
# proved unworkable
# worthwhile works
# cybernetists working
# prefer working
# housewife work
# society work
# work ellen
# analysis network
# network completed
# work dome
# your coworkers
# coworkers are
# work godda
# work ross
# energy workers
# work resulted
# rifle worked
# friend work
# sure works
# work run
# drawbridge works
# magnetometer working
# al work
# guesswork how
# workers thrown
# inexorable workings
# clumsy guesswork
# guesswork techniques
# mutations worked
# work asimovs
# homework might
# devil fireworks
# fireworks corporation
# sighed worked
# key workers
# workers supreme
# homework she
# works papers
# selected workers
# here worked
# female watchworker
# watchworker her
# a keyworker
# keyworker could
# young watchworker
# watchworker had
# the watchworker
# watchworker that
# watchworker could
# the watchworkers
# watchworkers became
# beloved workers
# disparate workers
# to workers
# workers far
# workers his
# watchworkers would
# worker selected
# the commonworker
# commonworker who
# that worker
# watchworker to
# fireworks company
# ordinary worker
# worker although
# inner workers
# worker hellstrom
# dependent workers
# female workers
# workers collided
# conditioned workers
# workers effectively
# emerging workers
# here workers
# worker climbed
# a watchworker
# watchworker was
# worker waved
# normal workers
# workers die
# workers breeders
# film work
# hand workers
# hysterical worker
# neutered worker
# neutered workers
# such workers
# workers toil
# produce workers
# incorruptible workers
# the sweepworkers
# sweepworkers had
# security workers
# workers discussing
# send workers
# younger workers
# young workers
# younger worker
# working carlos
# workers mostly
# frightened workers
# workers deserved
# discolored workers
# key worker
# worker roles
# young worker
# worker needed
# pocket workers
# workers already
# troop worked
# saldos workers
# workers moved
# countless workers
# worker stopped
# worker recognized
# sometimes workers
# workers miss
# nearby workers
# workers doing
# workers across
# alone work
# chief worker
# worker among
# worker specialists
# sells fireworks
# fireworks hellstrom
# any workers
# workers awareness
# hive worker
# worked having
# script worked
# of landworking
# landworking and
# healer works
# working hardship
# his worksuit
# worksuit valdez
# worksuit and
# idea worked
# weve work
# goals work
# sphygmomanometer worked
# work vanishes
# masters works
# mainstream work
# work manhandling
# space working
# anaidas work
# wang worked
# worked cozily
# geologists worked
# worked separately
# bananas worked
# work bananas
# idelers work
# precession worked
# quite worked
# work monday
# see fireworks
# fireworks must
# on fireworks
# work hellstrom
# cleanup workers
# workers peruges
# docs work
# work unexpectedly
# common worker
# working crews
# voiceless workers
# work peruge
# work anybody
# everyday worker
# worker she
# homework hellstrom
# workers driven
# common workers
# workers took
# end workers
# unspeaking workers
# workers response
# hydroponics workers
# post workers
# workers hellstrom
# workers tractable
# bustling workers
# surveillance workers
# hives workers
# at worker
# worker gestation
# several workers
# workers looked
# hive working
# biggie works
# realism framework
# stillness workers
# worker bred
# workers even
# working specialists
# tan work
# also work
# this fireworks
# than fireworks
# fireworks around
# work sister
# meet work
# nonfertile worker
# worker trained
# cloviss working
# working personality
# condition worked
# hive workers
# workers too
# metamorphosis worked
# technique worked
# tasks workers
# workers detailed
# hypedup workers
# workers arrayed
# through workers
# area workers
# guard workers
# armed workers
# workers which
# followed workers
# workers bodies
# adrenalinfilled workers
# workers all
# infuriated workers
# workers every
# immediately workers
# worker took
# while workers
# workers behind
# workers couldnt
# workers hope
# see workers
# stupid workers
# workers eat
# muscle working
# almost workers
# workers depended
# aeries workers
# workers sensing
# loose working
# galleries work
# work delayed
# a guardworker
# guardworker there
# fiftythree workers
# workers including
# dispatch workers
# frightened guardworker
# guardworker appeared
# workers around
# worker behind
# worker should
# faintly workers
# workers wearing
# dwarfed workers
# janvert worker
# investigated workers
# janverts work
# injured workers
# workers behavior
# workers read
# worker never
# colors workers
# celia working
# working among
# among working
# bruckner works
# longhair works
# work high
# thrill working
# work resupply
# work tseudi
# obviously works
# splintered woodwork
# woodwork tseudi
# working ship
# flying framework
# framework unpressurized
# works talk
# works considered
# lot working
# ...
# better works
# works basically
# newer works
# unnoticed works
# works come
# guesswork threats
# frozen firework
# firework displays
# to dworkin
# dworkin while
# dworkin after
# glory dworkin
# dworkin presented
# worked everywhere
# idiot work
# automat worked
# network his
# welfare workers
# migrant worker
# worker just
# work aniara
# work yours
# historical framework
# framework buckle
# by worked
# work union
# niust work
# plastosteel framework
# frenchys work
# work scribbled
# aging work
# productive workers
# retired work
# employed worker
# work anymore
# work opened
# radios works
# artwork his
# excellent artwork
# artwork he
# remedial workshop
# worship workshops
# converter working
# shed work
# near worked
# works appear
# institute work
# committee work
# institute working
# bombedout workshop
# workshop though
# line work
# laumers work
# work prophecy
# ornately worked
# worked leather
# work clafto
# breath worked
# labored worked
# worked busted
# worked despite
# backsters work
# dollar works
# diplomacy worked
# work christ
# connection networks
# in reworking
# reworking the
# intricate networks
# work paper
# clarion workshop
# workshop not
# tn workshop
# fiction working
# of breastworks
# breastworks my
# kaleidoscopic firework
# firework of
# works given
# worked sullenly
# jed working
# had workers
# work jed
# worked splendidly
# work damned
# either works
# work starts
# dopplers worked
# working colony
# barry workman
# work josep
# grillwork decorated
# sidney worked
# lady works
# work unpacking
# healing work
# committees working
# published works
# works definition
# crack fireworks
# fireworks exploding
# fannins handiwork
# handiwork bono
# fireworks against
# fireworks crack
# fireworks a
# worked twelve
# artwork used
# work crash
# were steelworkers
# steelworkers slapping
# work uh
# work signor
# native breastworks
# breastworks the
# the breastworks
# breastworks as
# tribunes work
# work whoever
# that workmen
# workmen researchers
# bored workmen
# workmen put
# satellite network
# amerilied workers
# aerospace workers
# clarisse work
# workshop yes
# oceanographical work
# work yourre
# simple workings
# whoevers working
# safe working
# working load
# work courts
# probable working
# fiction masterworks
# masterworks by
# hawkings work
# work disproving
# works cut
# identically teamwork
# teamwork demanded
# teamwork had
# work gev
# cat working
# hyor nohwork
# nohwork carlyle
# tissue works
# turmoil working
# cynthians working
# working directing
# worked murder
# worked harmon
# work opening
# keystone work
# cornerstone work
# guards worked
# dantes work
# spectacular fireworks
# square working
# really openwork
# openwork of
# decent work
# work finding
# soon worked
# floor work
# working webs
# work waited
# forth working
# and stonework
# stonework was
# down woodworker
# woodworker and
# working allen
# meat worked
# class working
# those patchwork
# patchwork demons
# benito work
# entertaining work
# and paperwork
# coffee work
# protestant work
# workers knee
# workers quickened
# workers straightened
# results worked
# working thrifty
# overworked jack
# nortons works
# poetic work
# work match
# worked eighteen
# slept worked
# excused work
# work fruitful
# fruitful work
# slacking work
# worked whered
# youve work
# works spent
# poison worked
# work maki
# work generating
# bay worked
# exploding fireworks
# fireworks something
# engineers worked
# edwards worked
# working iruerplanetary
# ericson work
# work dufour
# working banks
# work unmistakably
# pouts work
# work reprinted
# homework a
# manifestly works
# information networks
# networks had
# screens working
# homework answers
# ciub works
# work corbell
# peerssa worked
# onorous work
# dynamic working
# work collection
# skipping work
# neglecting work
# work readers
# networks whose
# scheme works
# works incidentally
# works sell
# evolution worked
# gyro work
# working shes
# poor intelligencework
# intelligencework and
# ronny works
# work ol
# galaxy working
# unworkable real
# made work
# work incentives
# electrodynamics works
# delanys work
# work rests
# savage work
# hardware worked
# framework really
# for workmen
# trellis work
# marvelous works
# work x
# work given
# memory working
# work printouts
# lotis working
# himyar working
# working casually
# worked beautifullyhelsa
# work toiling
# work fiftyfive
# rejuvenation work
# winner works
# occasionally works
# donkey work
# fireworks for
# work theii
# worked longer
# chemistry working
# bottom working
# working upwards
# art workshops
# workshops displays
# work leaves
# these workings
# workings ask
# dworkin sage
# oberon work
# adviser dworkin
# dworkin worse
# dworkins and
# and dworkin
# dworkin let
# unconscious guesswork
# guesswork sharing
# somehow worked
# her workbench
# workbench turning
# work awhile
# remembered dworkin
# dworkin wore
# from dworkin
# dworkin i
# become dworkin
# dworkin in
# what dworkin
# dworkin really
# odor dworkin
# dworkin stepped
# dworkin took
# noises dworkin
# dworkin grinned
# cavemouth dworkin
# dworkin stood
# oblique latticework
# latticework which
# radiant meshwork
# meshwork a
# position dworkin
# dworkin continued
# between dworkin
# dworkin and
# knows dworkin
# door dworkin
# dworkin extinguished
# now dworkin
# dworkin spoke
# workers manufacturing
# workable device
# decoder works
# work apologized
# diligent worker
# workers indistinguishable
# apartment overwork
# overwork it
# metaphor overworked
# orders worked
# works omnipotence
# were caseworkers
# caseworkers and
# network area
# clockwork cosmos
# work camps
# work life
# visiting dworkin
# dworkin a
# rag working
# network amplifies
# terran network
# work bear
# network world
# network calmly
# network central
# network bureaucracy
# against network
# network policy
# network craters
# network citizen
# visit dworkin
# dworkin our
# dad dworkin
# dworkin told
# guard dworkin
# dworkin s
# from dworkins
# dworkins desk
# dworkin than
# dworkins act
# anything dworkin
# dworkin fortunately
# dworkins narrative
# was dworkins
# dworkins i
# the footwork
# footwork it
# roofing work
# fellows working
# with dworkin
# dworkin gone
# workable approximation
# human worked
# works enough
# maria work
# light working
# worked bedroom
# the brightwork
# corbell worked
# booth worked
# worked demonically
# working hed
# work tooand
# dworkins trumps
# fled working
# even dworkin
# dworkin has
# dworkins lore
# work ganelon
# net work
# handsome artwork
# artwork send
# one workaholic
# workaholic to
# furious overwork
# overwork intervened
# supposedly working
# tennessee work
# work kt
# hans worked
# network floating
# work seelgaad
# work seemingly
# work thusly
# worked first
# working commercial
# working plant
# already works
# work usefully
# eventually work
# subway network
# elevators worked
# muscle work
# working phone
# massive work
# helstrom works
# works turned
# networks primarily
# electrical work
# work technically
# is works
# works about
# works sigfrid
# parents worked
# courseprogrammers working
# venusian work
# work white
# rusting girderworks
# girderworks few
# net working
# equals works
# work following
# stine worked
# working dean
# works quite
# gizmos worked
# works experimental
# chiropodist work
# of grillwork
# grillwork under
# work unmolested
# state worked
# seeing reworked
# reworked military
# working body
# boys working
# worked gording
# starts working
# identified work
# offbeat work
# work reta
# probe worked
# housework lately
# helmets work
# simulators work
# work wholl
# a workticket
# workticket that
# work symbiotieally
# corporation worked
# guesswork now
# gas works
# discovered worked
# doity work
# consultant work
# smash artwork
# artwork are
# its framework
# framework is
# ambitious work
# marriage works
# works splendidly
# inconsistencies worked
# working gravely
# network eastlake
# work adequately
# worked darting
# how working
# working watson
# drive worked
# working gone
# work loading
# work spiral
# work whether
# a workday
# a workcrew
# workcrew gravving
# scurryboy busywork
# busywork seemed
# working artist
# himself workwards
# workwards past
# kids works
# working efficiently
# publisher masterworks
# setties worked
# level working
# pack networks
# networks cover
# berker worked
# public network
# network fromm
# homework now
# network immediately
# network take
# over networks
# within networks
# networks nothing
# network demobilized
# conceived worked
# intelligence networks
# networks customary
# network centrals
# two network
# it network
# network how
# our handiwork
# handiwork about
# earth working
# poles worked
# worked magnificently
# equation works
# works anywhere
# eyes worked
# country working
# chosen works
# works another
# varleys work
# printed work
# work sharpening
# jumpdoors worked
# worked concepts
# waking workday
# workday busab
# a scrollwork
# scrollwork stand
# workable law
# white framework
# worker noted
# noted workers
# workers streaming
# electors workers
# mill workers
# work continuing
# a workshirt
# workshirt he
# explain working
# dreary overworked
# overworked boring
# working partner
# need work
# work mattin
# gallardos work
# ambitious artwork
# artwork than
# airbrush work
# lazarro worked
# this masterworks
# work gratefully
# work plus
# presently working
# fabians work
# gilk working
# working cgacy
# asteroid work
# education work
# work history
# titius work
# biological work
# work help
# dog work
# capmans work
# ling worked
# supply work
# worked weve
# jumpdoors work
# an worker
# the armorwork
# armorwork of
# plot worked
# gowachin work
# openwork metal
# wanting working
# laboratory worked
# worked beauti
# patients work
# with artwork
# artists working
# stipple work
# itself working
# motorcycle working
# phils work
# communitech work
# phil worked
# intent network
# thursdays working
# work corweiller
# clockwork on
# works cataloguing
# lover works
# operators working
# oscilloscope network
# century worked
# technologies work
# network she
# earphones worked
# was reworking
# few workmen
# workmen along
# workmen repaired
# lab worker
# takes working
# working minutes
# amazon artworks
# artworks describes
# workout we
# international work
# work assignment
# vat work
# hydroponics work
# work curiously
# works tomorrow
# working routine
# cap working
# work reiner
# work marianne
# from masterworks
# cloned work
# workers honest
# turbine working
# work near
# mine working
# ll work
# workable reactor
# framework moves
# work departed
# legal framework
# a workfare
# workfare crowd
# evacuation works
# work means
# anthologists working
# work quotation
# brunners work
# work divided
# dogwork roy
# work kevin
# worked nowadays
# work farrington
# worked campaigns
# working looked
# work dykes
# work hansen
# work naw
# works kevin
# set work
# working either
# working ellen
# small worktable
# worked whore
# worker what
# work studies
# turns working
# favorite work
# slime works
# ships work
# workers im
# refinery worker
# our worker
# refinery work
# worker than
# work greiner
# work furiously
# ellen worked
# work ellens
# work deadalus
# ceased working
# working couple
# work confined
# had workable
# workable solarpower
# working reactors
# symposia workshops
# worked sir
# societal framework
# gladys worked
# cyrils work
# dusty worker
# worker then
# worker spat
# worker glanced
# worker raised
# work pays
# work explode
# fever worked
# tomorrow working
# working rattrack
# works level
# artwork ace
# assign work
# provocative works
# work governments
# work henri
# fission worked
# daedalus worked
# refinery workers
# our workmen
# workmen you
# work shifts
# guesswork run
# working mines
# let work
# working equations
# work glenda
# worked ingenious
# work ttiey
# work whereupon
# business work
# work lucifers
# rights work
# doctor worked
# work thirty
# neil working
# worked barbara
# paperwork skirmishes
# xlitical legwork
# legwork that
# worked corwin
# dworkins performance
# dworkin he
# at dworkins
# dworkins having
# dworkin listen
# dworkin were
# dworkin if
# him dworkin
# recognize dworkins
# dworkins sitting
# hi dworkin
# dworkin hows
# followed dworkin
# dworkin along
# dworkin fully
# it dworkin
# dworkin fiona
# dworkin or
# indeed working
# apparent working
# business dworkin
# dworkin as
# like dworkins
# dworkins no
# pressure works
# works outward
# worked given
# bachutz worked
# mathematical work
# work part
# splendidly worked
# work enormously
# add working
# problems working
# changes work
# best works
# works lie
# formal works
# working incessantly
# work lining
# late works
# works something
# made working
# derivative works
# work shrugging
# doors worked
# basic working
# four workmen
# workmen wheeled
# work howard
# worked youve
# sculptor working
# worked gently
# newsmen worked
# network po
# lifework not
# working decks
# riser work
# homework properly
# return network
# network like
# network went
# bomb worked
# dworkin at
# dworkins quarters
# fans working
# stavros work
# work wondering
# working slower
# working matters
# worked seeming
# niun worked
# lips working
# worked exhausted
# critical framework
# hows work
# share work
# works erased
# easel working
# uh artwork
# serious works
# cqnstruction workers
# workers engineering
# work designing
# working moon
# was dworkin
# dworkin it
# so dworkin
# dworkin once
# begun working
# attunement work
# mental clockwork
# clockwork turning
# role work
# working whatever
# frank workman
# workman the
# freas work
# works laugh
# lines work
# work tortuously
# patchwork novel
# working paper
# everythings working
# work indistinguishable
# worker increases
# increased worker
# worker productivity
# the nonworking
# nonworking among
# railroad workers
# workers killed
# devices worked
# nuclear works
# works below
# working aft
# yifters handiwork
# working instrument
# work onworld
# hulagh working
# stopping work
# attrition worked
# artwork technology
# plot works
# assistant worked
# usually works
# psychological groundwork
# groundwork her
# work claiming
# use artwork
# artwork onto
# about artwork
# artwork how
# artwork improve
# others artwork
# works feature
# work rovins
# exact workings
# work laird
# workshops the
# gradually worked
# sea working
# duncan worked
# work resumed
# assembly network
# network swinging
# werent worked
# defense nerwork
# nerwork there
# bank working
# guesswork because
# worked nerve
# weiss working
# matter work
# process working
# nostrils worked
# reguls handiwork
# handiwork ill
# worked life
# little worker
# excessive workload
# workload and
# heroes work
# american working
# ending unworkable
# unworkable reading
# frivolous works
# scientific framework
# utility worker
# worker roy
# spielberg works
# works entirely
# trical worker
# encounters works
# work june
# shuffles paperwork
# working religiously
# vivekanandas works
# works tagores
# countries working
# shashi worked
# worked deftly
# work outlives
# often work
# work husain
# works bhargava
# renana working
# working secretly
# work uncompleted
# staff workers
# civilians work
# work saw
# work brokers
# grub work
# craftsmans lifework
# lifework in
# plus workable
# workable instincts
# worked rhandra
# i reworked
# reworked myself
# informant network
# steinbecks work
# work casts
# davidsons work
# plant worker
# worker exposure
# workhorse jet
# working unseen
# work laid
# working bronze
# forge working
# working metal
# europeans work
# extended working
# sensor network
# worked earth
# quarn works
# suborbital work
# worked nearby
# tonjis work
# eye worked
# worked rasping
# finegrained work
# work beneath
# a steelworkers
# steelworkers thigh
# are hackwork
# hackwork all
# cartiers work
# american workers
# workers belongs
# sagans work
# export workers
# workers or
# the workspace
# workspace the
# social work
# working dalehouse
# working looking
# navigator works
# information network
# network plus
# working worrying
# overworked i
# disembowelment working
# work pp
# work eternally
# lasting work
# more fireworky
# fireworky still
# fusion works
# works wind
# x worksheet
# worksheet sandworms
# works saving
# sought workable
# workable ores
# hyotte worked
# blair worked
# brakes work
# the grillework
# grillework my
# work applied
# off fireworks
# working viewer
# fireworks like
# a workingclass
# workingclass neighborhood
# exploded working
# work alien
# dicksons works
# work reviewed
# fabian working
# washington workers
# hanford workers
# worked largely
# gravity working
# work involuntarily
# work lin
# worked other
# projects working
# working team
# weeks working
# work graysons
# working scientist
# worked henderson
# good paperwork
# get paperwork
# paperwork together
# work whomp
# drily working
# balloon working
# demonstrably workable
# with fireworks
# contains work
# network set
# interior workings
# murk working
# my handiwork
# handiwork lets
# hellish work
# work dal
# eyes working
# forthcoming work
# as workers
# workers pulled
# grandfathers worked
# works mack
# working head
# noncoms working
# formula worker
# worker normal
# formula workers
# workers strapped
# workers control
# work control
# worker less
# become worked
# or artwork
# artwork but
# goes working
# writers workshops
# workshops history
# of networks
# network dustry
# widespread network
# second work
# topic networking
# networking could
# network within
# information networking
# networks also
# computer networking
# networking the
# computer networks
# networks already
# networks existence
# networks will
# networks rather
# in networks
# networks via
# network should
# steam works
# complicated work
# basket working
# work cabin
# fireworks blown
# organizing working
# work menningers
# menningers work
# working give
# work written
# and workmanlike
# workmanlike display
# work establishes
# kalutas work
# sedate works
# shared working
# an artwork
# different work
# worked hp

# %%
beginWith = random.sample(possibles,1)[0]
story = generate_story(markov_model, start=beginWith, limit=1000)
print('Story Generated Is:\n\n')
print(story)
# Out:
# Story Generated Is:
#
#
# worked shed have to wait we may wait for the natural presence of supercooled water droplets from his face and arms and legs tingled i was first switched on was the fact that the withits the slashers but we discover just what all this up actually is another wanted their polynesian fertiles back seemed as broad as the question more than likely but had to be siding with the losers corner as we reach that place sends a delegation here its turned white not purple he was old but there was simultaneously trying to cultivate those guys mustve passed out so many of you two fellows in uniforms bending over the injured digit there must be brought forth my ring it glittered in the nine hells are we but its too late the fnool beamed cheerily major back in washington who had picked up the last time a couple of others in their cubicles in terror get him any closer muller warned to hell rionna some day ill pay you want me to do something for them just at second hand was red in the end of everything general finogenov paused a moment to mention it i do something that he had thought that one of tfie otfier corner of my eye i paused and came for him but he stumbled over the curb and drove into long meaningless wars well make a fire there we cant go on this planet which was my statue it looks different trom anything else in the department doesnt give a hoot about his pleading manner of standing upon every new world and learning from some far place the will is omnipotent in larger doses that is to be rich he paused to editorialize i might sound right even to the hesitations of demetrios would always mock as she raced along the walls its potential was conservatively estimated at seven perhaps when we will bill you later dept garden city n y if this apprentice system works why do the driving in after dark oh well growled flip weve only got four hours of manual labor on the surface blackie duquesne had no doubt of the protected games at a hundred and fifty thousand years and gain no benefit he loves to show off on mars but the nijjan was evidently prepared for he ate of the soil became more and more knocking he pressed a stud and closed his eyes with the glow left his mouth dry and i showed him that he would look like this whispered irving hoarsely he turned to tonji try to get the lighter springier steps of sam tullgren but which still drew the orange draperies a gloom and it would be the final jump they might need something to think about it this report has already seen at least two stories are so much the worse for you what im about to return but not in time to the site of operations it looked as if a navy cruiser doesnt come from machines and pleasures your world male or fun orjoth whats supposed to be exact they cheat on the new owners and even when i was marched out into that knowing of the undetectible presence of visiting extraterrestials but even the parent firms total sales throughout us are you sneering both of us lay punctured and picked a great big glow for the crusoe i scrambled up the bodies along with their eye stalks together so that the adaptoman institute taught a lesson in loneliness he suddenly felt that he was a drum in moons ears then he relaxed and enjoyed selves first i must get a license for a week her dainty tonnage ive not wed its as you say well go down there after id told drool to stay in the future name may be derived from a distance i heard the play twenty times this night in a dirty word to me that the light hits im going to be allowed to roam around by myself another of those behind his belt something huge like whales andrei says jovian whales have mutated into weapons both the yinein and reduced starvation world wide to turn in now mac on newsstands and passing it back to where the fetters cruelly tight on ganns wrists and elbows there were more drinks many more drinks well need x ergs for the prayerful tuning of it and look at the mans table as if we ourselves get around to that thing the new wave endeavors only rep ...
