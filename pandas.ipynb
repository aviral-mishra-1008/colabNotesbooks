# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_public.csv')   #basically its importing csv file read_csv('path')

# %% [markdown]
# Printing Data

# %%
df
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1             I am a student who is learning to code      Yes
# 1              2             I am a student who is learning to code       No
# 2              3  I am not primarily a developer, but I write co...      Yes
# 3              4                     I am a developer by profession       No
# 4              5                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 5664        5689             I am a student who is learning to code       No
# 5665        5690             I am a student who is learning to code      Yes
# 5666        5691                     I am a developer by profession      Yes
# 5667        5692                     I am a developer by profession      Yes
# 5668        5693                     I am a developer by profession       No
#
# ...

# %% [markdown]
# Shape attribute

# %%
df.shape   #this is an attribute and not a method so no ()
# Out:
# (5669, 85)

# %%
#info attribute reveals much more information like data type and other infi
df.info() #this is a method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5669 entries, 0 to 5668
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              5669 non-null   int64
#  1   MainBranch              5669 non-null   object
#  2   Hobbyist                5669 non-null   object
#  3   OpenSourcer             5669 non-null   object
#  4   OpenSource              5561 non-null   object
#  5   Employment              5569 non-null   object
#  6   Country                 5669 non-null   object
#  7   Student                 5563 non-null   object
#  8   EdLevel                 5519 non-null   object
#  9   UndergradMajor          4813 non-null   object
#  10  EduOther                5405 non-null   object
#  11  OrgSize                 4607 non-null   object
#  12  DevType                 5208 non-null   object
#  13  YearsCode               5634 non-null   object
# ...

# %%
#opening schema as a df
df_schema = pd.read_csv('/content/survey_results_schema.csv')

# %%
df
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1             I am a student who is learning to code      Yes
# 1              2             I am a student who is learning to code       No
# 2              3  I am not primarily a developer, but I write co...      Yes
# 3              4                     I am a developer by profession       No
# 4              5                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 5664        5689             I am a student who is learning to code       No
# 5665        5690             I am a student who is learning to code      Yes
# 5666        5691                     I am a developer by profession      Yes
# 5667        5692                     I am a developer by profession      Yes
# 5668        5693                     I am a developer by profession       No
#
# ...

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randint(1,823,(341,3)),index = [list(range(341))])

df
# Out:
#        0    1    2
# 0    260  775  303
# 1     46  442  570
# 2    670  710  261
# 3    297  209  389
# 4    659  315  228
# ..   ...  ...  ...
# 336  214  316  145
# 337  582  737  525
# 338  792  268  779
# 339  529  209  587
# 340  119  383  395
#
# [341 rows x 3 columns]

# %%
df[[0,1,2]][0:10]
# Out:
#      0    1    2
# 0  260  775  303
# 1   46  442  570
# 2  670  710  261
# 3  297  209  389
# 4  659  315  228
# 5   57  120  404
# 6  504  821  675
# 7  742  768  116
# 8  809  200  310
# 9  532  822  736

# %%
df[df>10]
# Out:
#          0      1      2
# 0    260.0  775.0  303.0
# 1     46.0  442.0  570.0
# 2    670.0  710.0  261.0
# 3    297.0  209.0  389.0
# 4    659.0  315.0  228.0
# ..     ...    ...    ...
# 336  214.0  316.0  145.0
# 337  582.0  737.0  525.0
# 338  792.0  268.0  779.0
# 339  529.0  209.0  587.0
# 340  119.0  383.0  395.0
#
# [341 rows x 3 columns]

# %%
np1 = np.random.rand(2,3)
np2 = np.random.rand(2,3)
np1+np2
# Out:
# array([[0.50806385, 1.33776072, 1.65700793],
#        [1.00080052, 0.88198505, 1.45444725]])

# %%
# df[0][4:6] = None
df.columns = ['Num1','Num2','Num3']
df.loc[(df.Num1>50),['Num2']] = 113
df
# Out:
#      Num1  Num2  Num3
# 0     260   113   303
# 1      46   442   570
# 2     670   113   261
# 3     297   113   389
# 4     659   113   228
# ..    ...   ...   ...
# 336   214   113   145
# 337   582   113   525
# 338   792   113   779
# 339   529   113   587
# 340   119   113   395
#
# [341 rows x 3 columns]

# %%
df['Num1'][3:9] = None

# %%
c = df['Num1'].max()
x = df.shape
for i in range(x[0]):
  df['Num1'][i] = df['Num1'][i]/c

# %%
x = df['Num1'].mean()
y = df['Num1'].std
y = std**(0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-50bfccf57a6b> in <cell line: 3>()
#       1 x = df['Num1'].mean()
#       2 y = df['Num1'].std
# ----> 3 y = std**(0.5)
#
# NameError: name 'std' is not defined

# %%
l = [10,32,3,23,112,31]
l_t = []
l_t.append(l[0])
for i in range(len(l)):
  l_s = []
  if i==0:
    pass
  else:
    for j in l_t:
      if l[i]>j:
        pass
      elif l[i]<j:
        x = l_t.index(j)
        l_t.insert(x,l[i])
        l_s.append(1)
        break
    if sum(l_s)==1:
      pass
    else:
      l_t.append(l[i])
print(l_t)
# Out:
# [3, 10, 23, 31, 32, 112]
